# %%
import pandas as pd
from coinmarketcap import Market
import numpy as np

# %%
coinmarketcap = Market()
market_summary = coinmarketcap.ticker(limit=100)
cmc_df = pd.DataFrame(market_summary)
cmc_df
# Out:
#    24h_volume_usd available_supply  cached                id last_updated  \
# 0    7320180000.0       16894225.0   False           bitcoin   1519946968
# 1    1899820000.0       97925130.0   False          ethereum   1519946953
# 2     477131000.0    39094802192.0   False            ripple   1519946941
# 3     481340000.0       16994638.0   False      bitcoin-cash   1519946953
# 4     684019000.0       55437483.0   False          litecoin   1519946941
# 5     287200000.0       65000000.0   False               neo   1519946948
# 6     185033000.0    25927070538.0   False           cardano   1519946955
# 7      46983600.0    18468102389.0   False           stellar   1519946943
# 8     212624000.0      701143856.0   False               eos   1519946951
# 9      42451700.0     2779530283.0   False              iota   1519946951
# 10     61190200.0       15777478.0   False            monero   1519946942
# 11    104439000.0        7914106.0   False              dash   1519946942
# ...

# %%
# LEt pull out the neccesssary columns create a new Dataframe then, we will sort and filter for our info 
slim_cmcap_df = cmc_df[["percent_change_24h","id","24h_volume_usd","rank", "price_usd", "price_btc", "symbol"]].sort_values("percent_change_24h", ascending=True)
slim_cmc_df = slim_cmcap_df.set_index('symbol', drop=False)
slim_cmc_df

if "CTR"in slim_cmc_df.symbol:
    print("NP")
else:
    print("FFFF")
# Out:
# FFFF

# %%
slim_cmc_df = slim_cmc_df.head(n=10)
trending = ["1st","2nd","3rd","4th","5th","6th","7th","8th","9th","10th"]
slim_cmc_df.index=trending 
slim_cmc_df
#slim_cmc_df_reindexed.head(n=10)
#slim_cmc_df_reindexed
# Out:
#      percent_change_24h           id 24h_volume_usd rank    price_usd  \
# 1st               -0.51     digixdao      8928620.0   75      185.331
# 2nd               -2.13    raiblocks     15280400.0   23      13.0816
# 3rd               -4.75         pivx    104216000.0   49      10.9188
# 4th               -9.05          kin      2224230.0   87  0.000401438
# 5th                0.13       tether   2946470000.0   24      1.00333
# 6th                0.87   cindicator     91904100.0   69     0.273601
# 7th               10.13       status    188086000.0   34     0.292293
# 8th               10.44  dragonchain      3087380.0   51      2.47968
# 9th                10.5      siacoin     35540300.0   28    0.0405539
# 10th              10.65         aion     11035900.0   73        4.864
#
#        price_btc
# 1st    0.0164142
# 2nd    0.0011586
# 3rd   0.00096705
# 4th   0.00000004
# 5th   0.00008886
# 6th   0.00002423
# 7th   0.00002589
# 8th   0.00021962
# 9th   0.00000359
# ...

# %%
slim_cmc_df[0:1]["price_usd"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ac48bf324e2> in <module>()
# ----> 1 slim_cmc_df[0:1]["price_usd"]
#
# NameError: name 'slim_cmc_df' is not defined

# %%
for index, row in slim_cmc_df.iterrows():
    name=row['id']
    price=row['price_usd']
    print(name +"the shit"+ price)
    #print(row['id'], row['price_usd'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-519bfa1d7d70> in <module>()
# ----> 1 for index, row in slim_cmc_df.iterrows():
#       2     name=row['id']
#       3     price=row['price_usd']
#       4     print(name +"the shit"+ price)
#       5     #print(row['id'], row['price_usd'])
#
# NameError: name 'slim_cmc_df' is not defined
